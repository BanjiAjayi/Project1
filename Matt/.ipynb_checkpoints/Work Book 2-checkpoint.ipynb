# %% [markdown]
# # Part 1 -  Does Renovation Effect House Price?

# %% [markdown]
# Here we will Ask 3 question:
#     1. Does the house price go down as the age of the building increase?
#     2. Does the the house price go down as time since renovation increases?
#     3. If the house was not renovated:
#            ->  Does the house price decrecre more than if it would have been renovated.

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
df = pd.read_csv('kc_house_data_clean.csv')
df.head()
# Out:
#    Unnamed: 0          id        date     price  bedrooms  bathrooms  \
# 0           0  7129300520  10/13/2014  221900.0         3       1.00
# 1           1  6414100192   12/9/2014  538000.0         3       2.25
# 2           2  5631500400   2/25/2015  180000.0         2       1.00
# 3           3  2487200875   12/9/2014  604000.0         4       3.00
# 4           4  1954400510   2/18/2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...     long  sqft_living15  \
# 0         1180      5650     1.0         0.0  ... -122.257           1340
# 1         2570      7242     2.0         0.0  ... -122.319           1690
# 2          770     10000     1.0         0.0  ... -122.233           2720
# 3         1960      5000     1.0         0.0  ... -122.393           1360
# 4         1680      8080     1.0         0.0  ... -122.045           1800
#
#    sqft_lot15  year  month  day  month_year   price_bands  price_list_level  \
# 0        5650  2014     10   13     13-2014  200K to 300K                 3
# 1        7639  2014     12    9      9-2014  500K to 600K                 6
# 2        8062  2015      2   25     25-2015  100K to 200K                 2
# 3        5000  2014     12    9      9-2014  600K to 700K                 7
# 4        7503  2015      2   18     18-2015  500K to 600K                 6
#
#    yr_built_bands
# 0            1950
# 1            1950
# 2            1930
# 3            1960
# 4            1980
#
# [5 rows x 29 columns]

# %%
feilds = list(df.columns)
feilds
# Out:
# ['Unnamed: 0',
#  'id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15',
#  'year',
#  'month',
#  'day',
#  'month_year',
#  'price_bands',
#  'price_list_level',
#  'yr_built_bands']

# %%
df.corr()
# Out:
#                   Unnamed: 0        id     price  bedrooms  bathrooms  \
# Unnamed: 0          1.000000  0.006733  0.027465  0.009061   0.107139
# id                  0.006733  1.000000 -0.016776  0.002322   0.005126
# price               0.027465 -0.016776  1.000000  0.315950   0.525886
# bedrooms            0.009061  0.002322  0.315950  1.000000   0.527870
# bathrooms           0.107139  0.005126  0.525886  0.527870   1.000000
# sqft_living         0.044934 -0.012272  0.701915  0.593176   0.755741
# sqft_lot           -0.027167 -0.131923  0.089874  0.033599   0.088363
# floors              0.180107  0.018564  0.256789  0.183694   0.502547
# waterfront         -0.007696 -0.003603  0.264310 -0.002056   0.063625
# view               -0.013357  0.011758  0.393498  0.080736   0.186000
# condition          -0.095739 -0.023730  0.036003  0.023429  -0.126493
# grade               0.082358  0.008161  0.667958  0.366167   0.665833
# sqft_above          0.072320 -0.010842  0.605378  0.492537   0.686655
# sqft_basement      -0.040186 -0.004345  0.321084  0.303509   0.278476
# yr_built            0.199893  0.021590  0.053967  0.160737   0.507193
# yr_renovated       -0.021745 -0.010621  0.117852  0.018622   0.047163
# zipcode            -0.002022 -0.008214 -0.053479 -0.158624  -0.204895
# lat                 0.000833 -0.001794  0.306628 -0.011637   0.024160
# long                0.008847  0.020637  0.022028  0.136554   0.224872
# sqft_living15       0.026768 -0.002748  0.585247  0.404524   0.569850
# sqft_lot15         -0.030302 -0.138570  0.082852  0.031893   0.088303
# year               -0.001466  0.009882  0.003704 -0.009159  -0.026640
# month               0.001490 -0.011585 -0.009950 -0.000802   0.007506
# day                 0.002947  0.002197 -0.014644 -0.009514  -0.005065
# price_list_level    0.034696 -0.006079  0.822727  0.342545   0.518502
# yr_built_bands      0.198394  0.020660  0.055349  0.160627   0.505856
#
#                   sqft_living  sqft_lot    floors  waterfront      view  ...  \
# Unnamed: 0           0.044934 -0.027167  0.180107   -0.007696 -0.013357  ...
# id                  -0.012272 -0.131923  0.018564   -0.003603  0.011758  ...
# price                0.701915  0.089874  0.256789    0.264310  0.393498  ...
# bedrooms             0.593176  0.033599  0.183694   -0.002056  0.080736  ...
# bathrooms            0.755741  0.088363  0.502547    0.063625  0.186000  ...
# sqft_living          1.000000  0.173446  0.353913    0.104634  0.281703  ...
# sqft_lot             0.173446  1.000000 -0.004830    0.021457  0.075050  ...
# floors               0.353913 -0.004830  1.000000    0.020790  0.028389  ...
# waterfront           0.104634  0.021457  0.020790    1.000000  0.380543  ...
# view                 0.281703  0.075050  0.028389    0.380543  1.000000  ...
# condition           -0.059428 -0.008810 -0.264048    0.016657  0.045655  ...
# grade                0.762774  0.114723  0.458771    0.082815  0.249071  ...
# sqft_above           0.876445  0.184131  0.523955    0.071774  0.165999  ...
# sqft_basement        0.428667  0.015034 -0.241879    0.083052  0.270635  ...
# yr_built             0.318149  0.052939  0.489186   -0.024491 -0.054464  ...
# yr_renovated         0.051048  0.004976  0.003777    0.073938  0.090334  ...
# zipcode             -0.199876 -0.129598 -0.059587    0.028921  0.085050  ...
# lat                  0.052083 -0.085531  0.049195   -0.012163  0.006304  ...
# long                 0.241186  0.230220  0.125897   -0.037633 -0.077722  ...
# sqft_living15        0.756388  0.144752  0.280041    0.083820  0.278914  ...
# sqft_lot15           0.184343  0.718204 -0.010733    0.030657  0.073080  ...
# year                -0.029064  0.005616 -0.022412   -0.005023  0.001219  ...
# month                0.012084 -0.002596  0.014216    0.008197 -0.005171  ...
# day                 -0.007331  0.000271 -0.006396    0.013728  0.010671  ...
# price_list_level     0.669371  0.102090  0.297807    0.128953  0.325519  ...
# yr_built_bands       0.318483  0.054515  0.489031   -0.023974 -0.053845  ...
#
#                    zipcode       lat      long  sqft_living15  sqft_lot15  \
# Unnamed: 0       -0.002022  0.000833  0.008847       0.026768   -0.030302
# id               -0.008214 -0.001794  0.020637      -0.002748   -0.138570
# price            -0.053479  0.306628  0.022028       0.585247    0.082852
# bedrooms         -0.158624 -0.011637  0.136554       0.404524    0.031893
# bathrooms        -0.204895  0.024160  0.224872       0.569850    0.088303
# sqft_living      -0.199876  0.052083  0.241186       0.756388    0.184343
# sqft_lot         -0.129598 -0.085531  0.230220       0.144752    0.718204
# floors           -0.059587  0.049195  0.125897       0.280041   -0.010733
# waterfront        0.028921 -0.012163 -0.037633       0.083820    0.030657
# view              0.085050  0.006304 -0.077722       0.278914    0.073080
# condition         0.002794 -0.015273 -0.105814      -0.093012   -0.003092
# grade            -0.185809  0.113559  0.200316       0.713859    0.120976
# sqft_above       -0.261625 -0.001238  0.344810       0.731747    0.195073
# sqft_basement     0.073218  0.109776 -0.142362       0.199299    0.015895
# yr_built         -0.347213 -0.148353  0.409977       0.326363    0.070767
# yr_renovated      0.062392  0.027963 -0.064555       0.000666    0.004283
# zipcode           1.000000  0.266627 -0.564312      -0.279376   -0.147293
# lat               0.266627  1.000000 -0.135398       0.048624   -0.086135
# long             -0.564312 -0.135398  1.000000       0.335590    0.255580
# sqft_living15    -0.279376  0.048624  0.335590       1.000000    0.183513
# sqft_lot15       -0.147293 -0.086135  0.255580       0.183513    1.000000
# year              0.001259 -0.029047  0.000256      -0.021614    0.000154
# month            -0.000172  0.014955 -0.008422       0.002480    0.003187
# day              -0.002885 -0.015281 -0.007499      -0.008720   -0.003498
# price_list_level -0.038716  0.426636  0.053089       0.614592    0.093078
# yr_built_bands   -0.343339 -0.148895  0.409409       0.327300    0.070791
#
#                       year     month       day  price_list_level  \
# Unnamed: 0       -0.001466  0.001490  0.002947          0.034696
# id                0.009882 -0.011585  0.002197         -0.006079
# price             0.003704 -0.009950 -0.014644          0.822727
# bedrooms         -0.009159 -0.000802 -0.009514          0.342545
# bathrooms        -0.026640  0.007506 -0.005065          0.518502
# sqft_living      -0.029064  0.012084 -0.007331          0.669371
# sqft_lot          0.005616 -0.002596  0.000271          0.102090
# floors           -0.022412  0.014216 -0.006396          0.297807
# waterfront       -0.005023  0.008197  0.013728          0.128953
# view              0.001219 -0.005171  0.010671          0.325519
# condition        -0.045847  0.022398 -0.004718          0.042028
# grade            -0.030672  0.008972 -0.012530          0.686976
# sqft_above       -0.023837  0.010127 -0.002596          0.585920
# sqft_basement    -0.014997  0.007081 -0.010982          0.288889
# yr_built          0.003549 -0.006242 -0.005944          0.062084
# yr_renovated     -0.019725  0.007643  0.007546          0.106812
# zipcode           0.001259 -0.000172 -0.002885         -0.038716
# lat              -0.029047  0.014955 -0.015281          0.426636
# long              0.000256 -0.008422 -0.007499          0.053089
# sqft_living15    -0.021614  0.002480 -0.008720          0.614592
# sqft_lot15        0.000154  0.003187 -0.003498          0.093078
# year              1.000000 -0.782370 -0.006017          0.004228
# month            -0.782370  1.000000 -0.060738         -0.015176
# day              -0.006017 -0.060738  1.000000         -0.015863
# price_list_level  0.004228 -0.015176 -0.015863          1.000000
# yr_built_bands    0.004200 -0.007098 -0.006607          0.063469
#
#                   yr_built_bands
# Unnamed: 0              0.198394
# id                      0.020660
# price                   0.055349
# bedrooms                0.160627
# bathrooms               0.505856
# sqft_living             0.318483
# sqft_lot                0.054515
# floors                  0.489031
# waterfront             -0.023974
# view                   -0.053845
# condition              -0.363211
# grade                   0.445581
# sqft_above              0.425733
# sqft_basement          -0.132679
# yr_built                0.995211
# yr_renovated           -0.199227
# zipcode                -0.343339
# lat                    -0.148895
# long                    0.409409
# sqft_living15           0.327300
# sqft_lot15              0.070791
# year                    0.004200
# month                  -0.007098
# day                    -0.006607
# price_list_level        0.063469
# yr_built_bands          1.000000
#
# [26 rows x 26 columns]

# %%
df_corr_heatmap = df.drop(columns=['Unnamed: 0', 'id', 'lat', 'long', 'year', 'month', 'day',])
corr = df_corr_heatmap.corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True)
fig, ax = plt.subplots(figsize=(30, 15))
ax = sns.heatmap(corr, cmap=cmap, vmax=.3, center=0, annot=True,
            square=True, linewidths=1, cbar_kws={"shrink": 1})

# %%
# corr = df_corr_heatmap.corr()['price'].sort_values(ascending=False)
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
# fig, ax = plt.subplots(figsize=(30, 15))
# ax = sns.heatmap(corr, cmap=cmap, vmax=.3, center=0, annot=True,
#             square=True, linewidths=1, cbar_kws={"shrink": 1})

# %% [markdown]
# ## Add in Correlation Calculator

# %%
def mean_normalize(var):
    norm = []
    
    mean = sum(var)/len(var)
    
    for i in var:
        norm.append(i-mean)
    
    return norm

def dot_product(x, y):
    prodcut = 0
    
    for i in range(len(x)):
        prd = x[i]*y[i]
        prodcut += prd
    return prodcut

def covariance(var1, var2):
    n = len(var1)
    x = mean_normalize(var1)
    y = mean_normalize(var2)
    
    dot_product(x, y)
    
def correlation(var1, var2): # Calculates the "r" value.
    
    if len(var1) != len(var2):
        return 'The lengths of both the lists should be equal.' 
    else: 
       
        mean_norm_var1 = mean_normalize(var1)
        mean_norm_var2 = mean_normalize(var2)
        
        var1_dot_var2 = dot_product(mean_norm_var1, mean_norm_var2)
        
        var1_squared = [i * i for i in mean_norm_var1]
        var2_squared = [i * i for i in mean_norm_var2]
        
        return round(var1_dot_var2 / math.sqrt(sum(var1_squared) * sum(var2_squared)), 3)

# %% [markdown]
# ## Add Regrestion Line Calculator

# %%
def calc_slope(xs, ys):

    m = (((np.mean(xs)*np.mean(ys)) - np.mean(xs*ys)) /
         ((np.mean(xs)**2) - np.mean(xs*xs)))
    
    return m

def calc_intercept(xs, ys):

    m = calc_slope(xs, ys)
    c = np.mean(ys) - m*np.mean(xs)
    
    return c

def reg_line (m, c, X):
    
    return [(m*x)+c for x in X]

def sum_sq_err(ys_real, ys_predicted):

    sse =  sum((ys_predicted - ys_real) * (ys_predicted - ys_real))
    
    return sse

def r_squared(ys_real, ys_predicted):
    
    # Calculate Y_mean , squared error for regression and mean line , and calculate r-squared
    y_mean = [np.mean(ys_real) for y in ys_real]

    sq_err_reg = sum_sq_err(ys_real, ys_predicted)
    sq_err_y_mean = sum_sq_err(ys_real, y_mean)
    
    # Calculate r-squared 
    r_sq =  1 - (sq_err_reg/sq_err_y_mean)
    
    return r_sq

def reg_basic_and_plot(X, Y, title, X_Lable, Y_Lable):
    
    m = calc_slope(X,Y)
    c = calc_intercept(X,Y)
    Y_pred = reg_line(m, c, X)
    r = correlation(X,Y)
    r_sqrd = r_squared(Y,Y_pred)
    
    print ('Basic Regression Diagnostics')
    print ('----------------------------')
    print ('Sample Size:', len(X))
    print ('Slope:', round(m, 3))
    print ('Y-Intercept:', round(c, 3))
    print ('Correlation:', r)
    print ('R-Squared:', round(r_sqrd, 3))
    print ('----------------------------')
    print ('Model: Y =',round(m, 2),'* X +', round(c, 2))
    
    plt.figure(figsize=(15,10))
    plt.scatter(X, Y, color='#003F72', label='data')
    plt.plot(X, Y_pred, label='regression line')
    plt.xlabel(X_Lable)
    plt.ylabel(Y_Lable)
    plt.title(title)
    plt.legend(loc=2)
    plt.show()
    return None

def compare_reg_basic_and_plot(X, Y, L, P, title, X_Lable, Y_Lable):
    
    # X & Y Results
    m1 = calc_slope(X,Y)
    c1 = calc_intercept(X,Y)
    Y_pred = reg_line(m1, c1, X)
    r1 = correlation(X,Y)
    r_sqrd1 = r_squared(Y,Y_pred)
    
    print ('Data_1 Regression Diagnostics')
    print ('----------------------------')
    print ('Sample Size:', len(X))
    print ('Slope:', round(m1, 2))
    print ('Y-Intercept:', round(c1, 2))
    print ('Correlation:', r1)
    print ('R-Squared:', round(r_sqrd1, 3))
    print ('----------------------------')
    print ('Model: Y =',round(m1, 2),'* X +', round(c1, 2))
    
    # L & P Results
    m2 = calc_slope(L,P)
    c2 = calc_intercept(L,P)
    P_pred = reg_line(m2, c2, L)
    r2 = correlation(X,Y)
    r_sqrd2 = r_squared(Y,Y_pred)
    
    print ('\n\nData_2 Regression Diagnostics')
    print ('----------------------------')
    print ('Sample Size:', len(L))
    print ('Slope:', round(m2, 2))
    print ('Y-Intercept:', round(c2, 2))
    print ('Correlation:', r2)
    print ('R-Squared:', round(r_sqrd2, 3))
    print ('----------------------------')
    print ('Model: Y =',round(m2, 2),'* X +', round(c2, 2))
    
    
    
    plt.figure(figsize=(15,10))
    plt.scatter(X, Y, color='blue', label='Data_1')
    plt.plot(X, Y_pred, label='regression line_1')
    plt.scatter(L, P, color='orange', label='Data_2')
    plt.plot(L, P_pred, label='regression line_2')
    plt.xlabel(X_Lable)
    plt.ylabel(Y_Lable)
    plt.title(title)
    plt.legend(loc=2)
    plt.show()
    return None

# %% [markdown]
# ## Create:  "age" column

# %%
now = 2016

# %%
df['age'] = now - df['yr_built']

# %% [markdown]
# ## Create a column Renovated Yes/No

# %%
is_renovated = df['yr_renovated']
is_renovated.describe().apply(lambda x: format(x, 'f'))
temp = []
for ren in is_renovated:
    if ren > 0:
        temp.append('renovated')
    else:
        temp.append('not_renovated')
        
df['is_ren'] = temp

# %%
df['is_ren'].unique()
# Out:
# array(['not_renovated', 'renovated'], dtype=object)

# %% [markdown]
# # Create: Sale Count column
#         - shows if this property is on the list mulitiple times

# %%
# dup_houses_count = dup_counter(df['id'])
# print(len(dup_houses_count))
# dup_houses_count[:5]

# %% [markdown]
# Create a new DataFrame soreted by Date sold.

# %%
df.head()
# Out:
#    Unnamed: 0          id        date     price  bedrooms  bathrooms  \
# 0           0  7129300520  10/13/2014  221900.0         3       1.00
# 1           1  6414100192   12/9/2014  538000.0         3       2.25
# 2           2  5631500400   2/25/2015  180000.0         2       1.00
# 3           3  2487200875   12/9/2014  604000.0         4       3.00
# 4           4  1954400510   2/18/2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  sqft_lot15  year  month  \
# 0         1180      5650     1.0         0.0  ...        5650  2014     10
# 1         2570      7242     2.0         0.0  ...        7639  2014     12
# 2          770     10000     1.0         0.0  ...        8062  2015      2
# 3         1960      5000     1.0         0.0  ...        5000  2014     12
# 4         1680      8080     1.0         0.0  ...        7503  2015      2
#
#    day  month_year   price_bands  price_list_level  yr_built_bands  age  \
# 0   13     13-2014  200K to 300K                 3            1950   61
# 1    9      9-2014  500K to 600K                 6            1950   65
# 2   25     25-2015  100K to 200K                 2            1930   83
# 3    9      9-2014  600K to 700K                 7            1960   51
# 4   18     18-2015  500K to 600K                 6            1980   29
#
#           is_ren
# 0  not_renovated
# 1      renovated
# 2  not_renovated
# 3  not_renovated
# 4  not_renovated
#
# [5 rows x 31 columns]

# %%
df_sorted_date = df

# %%
pd.to_datetime(df_sorted_date['date'], format='%Y%m%d', errors='ignore')
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21590     5/21/2014
# 21591     2/23/2015
# 21592     6/23/2014
# 21593     1/16/2015
# 21594    10/15/2014
# Name: date, Length: 21595, dtype: object

# %%
df_sorted_date.set_index('date', inplace=True)

# %%
df_sorted_date.sort_index(ascending=False, inplace=True)

# %% [markdown]
# Create list of unique values:

# %%
unique_ids = list(df['id'].unique())
unique_ids[:4]
# Out:
# [7227800055, 1421069123, 3323069084, 7227500450]

# %% [markdown]
# Add a counter column to the datalist:

# %%
def id_with_counter(data):
    dup_dict = {}
    values = sorted(list(map(lambda x: x, data)))
    
    for val in values:
            dup_dict[val] = 1

    return dup_dict

# %%
unique_ids_dict = id_with_counter(unique_ids)
unique_ids_dict[1000102]
# Out:
# 1

# %% [markdown]
# Now we use this to iterate through the DataFrame list of id's. If it finds the id it;
#
# first appends the number next to the unique_id list
# the added 1 to that number.

# %%
def ocurrance_finder(data, unique_dict):
    new_list = []
    
    for d in data:
        for u, v in unique_dict.items():
            if d == u:
                new_list.append(v)
                unique_dict[u] += 1
    return new_list

# %% [markdown]
# Apply occurance finder to the soreted data set.

# %%
sale_count_list = ocurrance_finder(df_sorted_date['id'], unique_ids_dict)
print(len(sale_count_list))
df_sorted_date.shape
# Out:
# 21595
# (21595, 30)

# %%
df_sorted_date['sale_count'] = sale_count_list

# %%
df_sorted_date.head()
# Out:
#           Unnamed: 0          id      price  bedrooms  bathrooms  sqft_living  \
# date
# 9/9/2014       10904  7227800055   199500.0         4       2.00         1750
# 9/9/2014       12826  1421069123   214000.0         3       1.00         1020
# 9/9/2014        1322  3323069084   620000.0         4       2.50         1840
# 9/9/2014        8204  7227500450   222900.0         2       1.00          860
# 9/9/2014       18353  1370803445  1140000.0         4       1.75         3080
#
#           sqft_lot  floors  waterfront  view  ...  year  month  day  \
# date                                          ...
# 9/9/2014      8116     1.0         0.0   0.0  ...  2014      9    9
# 9/9/2014      9147     1.0         0.0   0.0  ...  2014      9    9
# 9/9/2014    220308     2.0         0.0   0.0  ...  2014      9    9
# 9/9/2014      5800     1.0         0.0   0.0  ...  2014      9    9
# 9/9/2014      6500     1.0         0.0   0.0  ...  2014      9    9
#
#           month_year   price_bands  price_list_level  yr_built_bands  age  \
# date
# 9/9/2014      9-2014  100K to 200K                 2            1940   73
# 9/9/2014      9-2014  200K to 300K                 3            1900  116
# 9/9/2014      9-2014  600K to 700K                 7            2000   16
# 9/9/2014      9-2014  200K to 300K                 3            1940   74
# 9/9/2014      9-2014    900K to 1M                10            1940   75
#
#                  is_ren  sale_count
# date
# 9/9/2014  not_renovated           1
# 9/9/2014      renovated           1
# 9/9/2014  not_renovated           1
# 9/9/2014  not_renovated           1
# 9/9/2014  not_renovated           1
#
# [5 rows x 31 columns]

# %%
df_sorted_date['sale_count'].unique()
# Out:
# array([1, 2, 3])

# %% [markdown]
# ### Using this, can we see if a house which has been sold for a second time has had a renovation done? And has that had an efect on its price.

# %% [markdown]
# This is probable done by extracting the id's which occure multiple times into a new data frame.
#
#     1. Create a list id's of the duplicated ids
#     2. Use list to extract

# %%
def dup_counter(data):
    dup_dict = {}
    dup_list = []
    values = sorted(list(map(lambda x: x, data)))
    
    for val in values:
        if val in dup_dict: 
            dup_dict[val] += 1
        else:
            dup_dict[val] = 1

    sorted_dup_dict = sorted(dup_dict.items(), key = lambda x: x[1], reverse = True)
    dup_temp = list(sorted_dup_dict)
    
    for d in dup_temp:
        if d[1] > 1:
            dup_list.append(d)
    return dup_list

# %%
dup_ids_list = dup_counter(df['id'])
dup_ids_list[:4]
# Out:
# [(795000620, 3), (1000102, 2), (7200179, 2), (109200390, 2)]

# %%
def just_ids(data):
    new_list = []
    for d in dup_ids_list:
        new_list.append(d[0])
    return new_list

# %%
dup_ids = just_ids(dup_ids_list)

# %%
dup_ids[:4]
# Out:
# [795000620, 1000102, 7200179, 109200390]

# %% [markdown]
# In this we will try to extract the ids in this list to a new DataFrame:

# %%
df_multi_sale = df_sorted_date[df_sorted_date['id'].isin(dup_ids)]

# %%
df_multi_sale.head()
# Out:
#           Unnamed: 0          id     price  bedrooms  bathrooms  sqft_living  \
# date
# 9/9/2014       10904  7227800055  199500.0         4        2.0         1750
# 9/9/2014        1127  8062900070  272000.0         5        1.5         2550
# 9/5/2014        5966  1545800290  215000.0         4        2.5         1700
# 9/5/2014        3619  2767602141  525000.0         3        1.5         1380
# 9/5/2014       10261  1450100390  125000.0         3        1.0          920
#
#           sqft_lot  floors  waterfront  view  ...  year  month  day  \
# date                                          ...
# 9/9/2014      8116     1.0         0.0   0.0  ...  2014      9    9
# 9/9/2014      6300     1.0         0.0   0.0  ...  2014      9    9
# 9/5/2014      6675     2.0         0.0   0.0  ...  2014      9    5
# 9/5/2014      4290     1.0         0.0   0.0  ...  2014      9    5
# 9/5/2014      7314     1.0         0.0   0.0  ...  2014      9    5
#
#           month_year   price_bands  price_list_level  yr_built_bands  age  \
# date
# 9/9/2014      9-2014  100K to 200K                 2            1940   73
# 9/9/2014      9-2014  200K to 300K                 3            1950   57
# 9/5/2014      5-2014  200K to 300K                 3            1990   19
# 9/5/2014      5-2014  500K to 600K                 6            1950   61
# 9/5/2014      5-2014  100K to 200K                 2            1960   56
#
#                  is_ren  sale_count
# date
# 9/9/2014  not_renovated           1
# 9/9/2014  not_renovated           1
# 9/5/2014  not_renovated           1
# 9/5/2014  not_renovated           1
# 9/5/2014  not_renovated           1
#
# [5 rows x 31 columns]

# %%
df_multi_sale.shape
# Out:
# (353, 31)

# %%
df_mulit_sale_1 = df_multi_sale.loc[df_multi_sale['sale_count'] == 1]
df_mulit_sale_1.describe()
# Out:
#          Unnamed: 0            id         price    bedrooms   bathrooms  \
# count    176.000000  1.760000e+02  1.760000e+02  176.000000  176.000000
# mean   10207.505682  4.545319e+09  3.930217e+05    3.284091    1.805398
# std     5643.429923  2.875605e+09  2.929008e+05    1.030383    0.736875
# min       93.000000  1.000102e+06  8.500000e+04    1.000000    0.750000
# 25%     5711.750000  1.989975e+09  2.231250e+05    3.000000    1.000000
# 50%    10244.000000  4.085211e+09  3.129750e+05    3.000000    1.750000
# 75%    14971.750000  7.433280e+09  4.576250e+05    4.000000    2.250000
# max    21565.000000  9.834201e+09  1.900000e+06    6.000000    4.500000
#
#        sqft_living       sqft_lot      floors  waterfront        view  ...  \
# count   176.000000     176.000000  176.000000       176.0  176.000000  ...
# mean   1743.920455   11665.380682    1.267045         0.0    0.136364  ...
# std     757.734197   22861.807303    0.433912         0.0    0.662149  ...
# min     580.000000    1092.000000    1.000000         0.0    0.000000  ...
# 25%    1220.000000    5544.250000    1.000000         0.0    0.000000  ...
# 50%    1620.000000    8011.500000    1.000000         0.0    0.000000  ...
# 75%    2080.000000   10110.000000    1.500000         0.0    0.000000  ...
# max    5290.000000  224442.000000    3.000000         0.0    4.000000  ...
#
#              long  sqft_living15     sqft_lot15         year       month  \
# count  176.000000     176.000000     176.000000   176.000000  176.000000
# mean  -122.237523    1777.170455   10673.386364  2014.295455    6.170455
# std      0.130698     611.692896   16489.243128     0.457549    2.104263
# min   -122.463000     810.000000    1334.000000  2014.000000    2.000000
# 25%   -122.337250    1360.000000    6000.000000  2014.000000    5.000000
# 50%   -122.284000    1610.000000    7950.000000  2014.000000    6.000000
# 75%   -122.172000    2020.000000    9587.250000  2015.000000    8.000000
# max   -121.734000    4060.000000  183897.000000  2015.000000   12.000000
#
#               day  price_list_level  yr_built_bands         age  sale_count
# count  176.000000        176.000000      176.000000  176.000000       176.0
# mean    16.488636          4.244318     1955.284091   56.238636         1.0
# std      8.613603          2.160019       25.274018   25.622755         0.0
# min      1.000000          1.000000     1900.000000    3.000000         1.0
# 25%      8.000000          3.000000     1940.000000   38.000000         1.0
# 50%     18.000000          4.000000     1950.000000   57.000000         1.0
# 75%     24.000000          5.000000     1970.000000   73.000000         1.0
# max     31.000000         10.000000     2010.000000  116.000000         1.0
#
# [8 rows x 28 columns]

# %%
df_mulit_sale_2 = df_multi_sale.loc[df_multi_sale['sale_count'] == 2]
df_mulit_sale_2.describe()
# Out:
#          Unnamed: 0            id         price    bedrooms   bathrooms  \
# count    176.000000  1.760000e+02  1.760000e+02  176.000000  176.000000
# mean   10207.852273  4.545319e+09  4.479699e+05    3.284091    1.805398
# std     5643.437914  2.875605e+09  2.947436e+05    1.030383    0.736875
# min       94.000000  1.000102e+06  8.200000e+04    1.000000    0.750000
# 25%     5710.750000  1.989975e+09  2.403500e+05    3.000000    1.000000
# 50%    10245.000000  4.085211e+09  3.700000e+05    3.000000    1.750000
# 75%    14970.750000  7.433280e+09  5.500000e+05    4.000000    2.250000
# max    21564.000000  9.834201e+09  1.940000e+06    6.000000    4.500000
#
#        sqft_living       sqft_lot      floors  waterfront        view  ...  \
# count   176.000000     176.000000  176.000000       176.0  176.000000  ...
# mean   1743.920455   11665.380682    1.267045         0.0    0.136364  ...
# std     757.734197   22861.807303    0.433912         0.0    0.662149  ...
# min     580.000000    1092.000000    1.000000         0.0    0.000000  ...
# 25%    1220.000000    5544.250000    1.000000         0.0    0.000000  ...
# 50%    1620.000000    8011.500000    1.000000         0.0    0.000000  ...
# 75%    2080.000000   10110.000000    1.500000         0.0    0.000000  ...
# max    5290.000000  224442.000000    3.000000         0.0    4.000000  ...
#
#              long  sqft_living15     sqft_lot15         year       month  \
# count  176.000000     176.000000     176.000000   176.000000  176.000000
# mean  -122.237523    1777.170455   10673.386364  2014.562500    6.136364
# std      0.130698     611.692896   16489.243128     0.497494    4.216110
# min   -122.463000     810.000000    1334.000000  2014.000000    1.000000
# 25%   -122.337250    1360.000000    6000.000000  2014.000000    2.000000
# 50%   -122.284000    1610.000000    7950.000000  2015.000000    4.000000
# 75%   -122.172000    2020.000000    9587.250000  2015.000000   11.000000
# max   -121.734000    4060.000000  183897.000000  2015.000000   12.000000
#
#               day  price_list_level  yr_built_bands         age  sale_count
# count  176.000000        176.000000      176.000000  176.000000       176.0
# mean    15.215909          4.772727     1955.284091   56.238636         2.0
# std      8.387676          2.217990       25.274018   25.622755         0.0
# min      1.000000          1.000000     1900.000000    3.000000         2.0
# 25%      7.750000          3.000000     1940.000000   38.000000         2.0
# 50%     16.000000          4.000000     1950.000000   57.000000         2.0
# 75%     22.250000          6.000000     1970.000000   73.000000         2.0
# max     31.000000         10.000000     2010.000000  116.000000         2.0
#
# [8 rows x 28 columns]

# %%
compare_reg_basic_and_plot(df_mulit_sale_1['age'], df_mulit_sale_1['price'], df_mulit_sale_2['age'], df_mulit_sale_2['price'], 
                           "Price Compared to Age of Property: \nData_1 = First Sale \nData_2 = Second Sale", "Age", "Price")
# Out:
# Data_1 Regression Diagnostics
# ----------------------------
# Sample Size: 176
# Slope: -3061.95
# Y-Intercept: 565221.7
# Correlation: -0.268
# R-Squared: 0.072
# ----------------------------
# Model: Y = -3061.95 * X + 565221.7
#
#
# Data_2 Regression Diagnostics
# ----------------------------
# Sample Size: 176
# Slope: -2143.4
# Y-Intercept: 568511.76
# Correlation: -0.268
# R-Squared: 0.072
# ----------------------------
# Model: Y = -2143.4 * X + 568511.76

# %% [markdown]
# For houses which were sold twice, the old the house the grater the price for the second sale.

# %%
compare_reg_basic_and_plot(df_mulit_sale_1['sqft_living'], df_mulit_sale_1['price'], df_mulit_sale_2['sqft_living'], df_mulit_sale_2['price'], 
                           "Price Compared to Square ft of Property: \nData_1 = First Sale \nData_2 = Second Sale", "sqft_living", "price")
# Out:
# Data_1 Regression Diagnostics
# ----------------------------
# Sample Size: 176
# Slope: 277.28
# Y-Intercept: -90539.9
# Correlation: 0.717
# R-Squared: 0.515
# ----------------------------
# Model: Y = 277.28 * X + -90539.9
#
#
# Data_2 Regression Diagnostics
# ----------------------------
# Sample Size: 176
# Slope: 273.41
# Y-Intercept: -28832.33
# Correlation: 0.717
# R-Squared: 0.515
# ----------------------------
# Model: Y = 273.41 * X + -28832.33

# %% [markdown]
# ## Create: age since renovation column

# %% [markdown]
# Creating the new column

# %%
temp_age_since_ren = df['yr_renovated']
temp = []
i = 0
for val in temp_age_since_ren:
    if val > 0:
        val = now - df['yr_renovated'][i]
        temp.append(val)
        i += 1
    else:
        val = now - df['yr_built'][i]
        temp.append(val)
        i += 1

df['age_since_ren'] = temp

# %%
df['age_since_ren'].unique()
# Out:
# array([ 73,  51,  16,  74,  75,  27,   3,  22,  48,   8,  14,  15,  41,
#         47,  30,  10,  60,  70,  38,  55,  91,  11,  29,   5,  52,  61,
#         49,  63,  92,  59,  44,   2,  33,  37,  57,  17,  18,  20, 103,
#         69,  94,  25,  31,  66,  13,  32,  64,  12,  35,  50,  34,  45,
#         72, 116,  98,   7,  42,  39,  96,  68,  65, 105,  56,  46,  36,
#         24, 114,  43,  93,  58,  67,  53,  26,  88, 110,   9,  79,  62,
#         19,  23,  76,  71, 109,  95,  89,  80,  28,   6,  54,  97, 100,
#        108,  40, 115,  84, 112,  86, 106,  21, 104,  77,  90, 107,  99,
#         85,  83,  78, 101, 111, 113,   4,  87,  81, 102,  82,   1])

# %%
print(df['age'].head())
print(df['age_since_ren'].head())
# Out:
# date
# 9/9/2014     73
# 9/9/2014    116
# 9/9/2014     16
# 9/9/2014     74
# 9/9/2014     75
# Name: age, dtype: int64
# date
# 9/9/2014    73
# 9/9/2014    51
# 9/9/2014    16
# 9/9/2014    74
# 9/9/2014    75
# Name: age_since_ren, dtype: int64

# %% [markdown]
# # Time to Renovation in Years

# %%
# print(df.agg({'yr_built' : ['sum', 'min', 'max', 'mean', 'median', 'mode']}))
# print(df.agg({'yr_renovated': ['sum', 'min', 'max', 'mean', 'median', 'mode']}))

# %%
# def time_to_renovation_cal (yr_built, yr_renovated)
#     if yr_renovated != 0:
#         Time_to_ren = yr_renovated - yr_built
#     else:
#         t

# %%
time_to_ren = df['yr_renovated'] - df['yr_built']
""" WARNING: if not renovated then this will = - yr_built only use this value for properties that have been renovated"""
df['time_to_ren'] = time_to_ren

# %%
df.head()
# Out:
#           Unnamed: 0          id      price  bedrooms  bathrooms  sqft_living  \
# date
# 9/9/2014       10904  7227800055   199500.0         4       2.00         1750
# 9/9/2014       12826  1421069123   214000.0         3       1.00         1020
# 9/9/2014        1322  3323069084   620000.0         4       2.50         1840
# 9/9/2014        8204  7227500450   222900.0         2       1.00          860
# 9/9/2014       18353  1370803445  1140000.0         4       1.75         3080
#
#           sqft_lot  floors  waterfront  view  ...  day  month_year  \
# date                                          ...
# 9/9/2014      8116     1.0         0.0   0.0  ...    9      9-2014
# 9/9/2014      9147     1.0         0.0   0.0  ...    9      9-2014
# 9/9/2014    220308     2.0         0.0   0.0  ...    9      9-2014
# 9/9/2014      5800     1.0         0.0   0.0  ...    9      9-2014
# 9/9/2014      6500     1.0         0.0   0.0  ...    9      9-2014
#
#            price_bands  price_list_level  yr_built_bands  age         is_ren  \
# date
# 9/9/2014  100K to 200K                 2            1940   73  not_renovated
# 9/9/2014  200K to 300K                 3            1900  116      renovated
# 9/9/2014  600K to 700K                 7            2000   16  not_renovated
# 9/9/2014  200K to 300K                 3            1940   74  not_renovated
# 9/9/2014    900K to 1M                10            1940   75  not_renovated
#
#           sale_count  age_since_ren  time_to_ren
# date
# 9/9/2014           1             73        -1943
# 9/9/2014           1             51           65
# 9/9/2014           1             16        -2000
# 9/9/2014           1             74        -1942
# 9/9/2014           1             75        -1941
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Create new column with the "log price"

# %% [markdown]
# Firstly lets take a look at the price distrobution.

# %%
sns.distplot(df['price'])

# %%
df['log_price'] = np.log(df['price'])
df.head()
# Out:
#           Unnamed: 0          id      price  bedrooms  bathrooms  sqft_living  \
# date
# 9/9/2014       10904  7227800055   199500.0         4       2.00         1750
# 9/9/2014       12826  1421069123   214000.0         3       1.00         1020
# 9/9/2014        1322  3323069084   620000.0         4       2.50         1840
# 9/9/2014        8204  7227500450   222900.0         2       1.00          860
# 9/9/2014       18353  1370803445  1140000.0         4       1.75         3080
#
#           sqft_lot  floors  waterfront  view  ...  month_year   price_bands  \
# date                                          ...
# 9/9/2014      8116     1.0         0.0   0.0  ...      9-2014  100K to 200K
# 9/9/2014      9147     1.0         0.0   0.0  ...      9-2014  200K to 300K
# 9/9/2014    220308     2.0         0.0   0.0  ...      9-2014  600K to 700K
# 9/9/2014      5800     1.0         0.0   0.0  ...      9-2014  200K to 300K
# 9/9/2014      6500     1.0         0.0   0.0  ...      9-2014    900K to 1M
#
#           price_list_level  yr_built_bands  age         is_ren  sale_count  \
# date
# 9/9/2014                 2            1940   73  not_renovated           1
# 9/9/2014                 3            1900  116      renovated           1
# 9/9/2014                 7            2000   16  not_renovated           1
# 9/9/2014                 3            1940   74  not_renovated           1
# 9/9/2014                10            1940   75  not_renovated           1
#
#           age_since_ren  time_to_ren  log_price
# date
# 9/9/2014             73        -1943  12.203570
# 9/9/2014             51           65  12.273731
# 9/9/2014             16        -2000  13.337475
# 9/9/2014             74        -1942  12.314479
# 9/9/2014             75        -1941  13.946539
#
# [5 rows x 34 columns]

# %% [markdown]
# Is the price is a logarithmly Scale?

# %%
log_price = np.log(df['price'])

# %%
sns.distplot(log_price)

# %% [markdown]
# # 1a. Data Frame - Renovated House's

# %% [markdown]
# Create a new DataFrame but just for houses which have been renovated

# %%
df_ren = df.loc[df['yr_renovated'] != 0]

# %%
df_ren.head()
# Out:
#           Unnamed: 0          id     price  bedrooms  bathrooms  sqft_living  \
# date
# 9/9/2014       12826  1421069123  214000.0         3       1.00         1020
# 9/9/2014        4764  4045500130  154000.0         2       1.00         1040
# 9/8/2014       14837  2301400276  865000.0         4       2.50         2520
# 9/8/2014          95  1483300570  905000.0         4       2.50         3300
# 9/8/2014        5577   537000130  360000.0         1       2.25         2060
#
#           sqft_lot  floors  waterfront  view  ...  month_year   price_bands  \
# date                                          ...
# 9/9/2014      9147     1.0         0.0   0.0  ...      9-2014  200K to 300K
# 9/9/2014     20524     1.0         0.0   3.0  ...      9-2014  100K to 200K
# 9/8/2014      4950     2.0         0.0   0.0  ...      8-2014  800K to 900K
# 9/8/2014     10250     1.0         0.0   0.0  ...      8-2014    900K to 1M
# 9/8/2014     10600     1.5         0.0   0.0  ...      8-2014  300K to 400K
#
#           price_list_level  yr_built_bands  age     is_ren  sale_count  \
# date
# 9/9/2014                 3            1900  116  renovated           1
# 9/9/2014                 2            1940   67  renovated           1
# 9/8/2014                 9            1900  110  renovated           1
# 9/8/2014                10            1940   70  renovated           1
# 9/8/2014                 4            1920   89  renovated           1
#
#           age_since_ren  time_to_ren  log_price
# date
# 9/9/2014             51           65  12.273731
# 9/9/2014             27           40  11.944708
# 9/8/2014             14           96  13.670485
# 9/8/2014             25           45  13.715690
# 9/8/2014             33           56  12.793859
#
# [5 rows x 34 columns]

# %%
df_ren.shape
# Out:
# (744, 34)

# %%
# g = sns.FacetGrid(df_ren, col="age",  row="grade")
# g = g.map(plt.hist, "log_price")

# %% [markdown]
# # 1b. DataFrame - Non_Renovated House's
#
# There was a house that it's year built was zero so it must be excluded from this data frame.

# %%
df_non_ren = df.loc[(df['yr_renovated'] == 0) & (df['yr_built'] != 0)]

# %%
df_non_ren.head()
# Out:
#           Unnamed: 0          id      price  bedrooms  bathrooms  sqft_living  \
# date
# 9/9/2014       10904  7227800055   199500.0         4       2.00         1750
# 9/9/2014        1322  3323069084   620000.0         4       2.50         1840
# 9/9/2014        8204  7227500450   222900.0         2       1.00          860
# 9/9/2014       18353  1370803445  1140000.0         4       1.75         3080
# 9/9/2014       10310   325049234   925000.0         4       2.50         3110
#
#           sqft_lot  floors  waterfront  view  ...  month_year   price_bands  \
# date                                          ...
# 9/9/2014      8116     1.0         0.0   0.0  ...      9-2014  100K to 200K
# 9/9/2014    220308     2.0         0.0   0.0  ...      9-2014  600K to 700K
# 9/9/2014      5800     1.0         0.0   0.0  ...      9-2014  200K to 300K
# 9/9/2014      6500     1.0         0.0   0.0  ...      9-2014    900K to 1M
# 9/9/2014     11422     2.0         0.0   0.0  ...      9-2014    900K to 1M
#
#           price_list_level  yr_built_bands  age         is_ren  sale_count  \
# date
# 9/9/2014                 2            1940   73  not_renovated           1
# 9/9/2014                 7            2000   16  not_renovated           1
# 9/9/2014                 3            1940   74  not_renovated           1
# 9/9/2014                10            1940   75  not_renovated           1
# 9/9/2014                10            1980   27  not_renovated           1
#
#           age_since_ren  time_to_ren  log_price
# date
# 9/9/2014             73        -1943  12.203570
# 9/9/2014             16        -2000  13.337475
# 9/9/2014             74        -1942  12.314479
# 9/9/2014             75        -1941  13.946539
# 9/9/2014             27        -1989  13.737549
#
# [5 rows x 34 columns]

# %% [markdown]
# ### If renovated: show the distributuion of time to renovation.

# %%
sns.distplot(df_ren['time_to_ren'])

# %%
reg_basic_and_plot(df_ren['time_to_ren'], df_ren['log_price'], 
                   "Time to Renovations compared to Price", "Years to Renovation", "Log Price")
# Out:
# Basic Regression Diagnostics
# ----------------------------
# Sample Size: 744
# Slope: 0.002
# Y-Intercept: 13.241
# Correlation: 0.071
# R-Squared: 0.005
# ----------------------------
# Model: Y = 0.0 * X + 13.24

# %% [markdown]
# Price is negliagble effected by time to renovation.

# %%
reg_basic_and_plot(df_ren['age'], df_ren['log_price'], 
                   "Time to Renovations compared to Price", "Age of Property", "Log Price")
# Out:
# Basic Regression Diagnostics
# ----------------------------
# Sample Size: 744
# Slope: -0.002
# Y-Intercept: 13.482
# Correlation: -0.064
# R-Squared: 0.004
# ----------------------------
# Model: Y = -0.0 * X + 13.48

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Datasets Sample Size

# %%
total_housing_units = 902107 # From American Comunity Survey 2017
housing_units = df.shape[0]
print("Total Number of properties in KC:", total_housing_units) 
print("Total Number of properties in DataSet:", len(unique_ids))
print("Percentage of properties:", round((((len(unique_ids))/total_housing_units)*100),3),"%")
# Out:
# Total Number of properties in KC: 902107
# Total Number of properties in DataSet: 21418
# Percentage of properties: 2.374 %

# %% [markdown]
# # Price compared to Age of property

# %%
reg_basic_and_plot(df['age'], df['log_price'], "Price compared to Age of property", "Age", "Log Price")

# %% [markdown]
# ### Price compared to: Time since renovation or if not renovated, Time since built.

# %%
reg_basic_and_plot(df['age_since_ren'], 
                   df['log_price'], 
                   "Price compared to: Time since renovation or if not renovated, Time since built.",
                  "Years Since Renovation Or Built",
                  "Log Price")

# %%
compare_reg_basic_and_plot(df_non_ren['age'], df_non_ren['log_price'], 
                           df_ren['age'], df_ren['log_price'], 
                           "Price Compared to Year Built: \nData_1 = Non-Renovated \nData_2 = Renovated",
                          "Age", "Log Price",)

# %%
print(df_ren['age'].median())
print(df_non_ren['age'].median())


print(df_ren['age_since_ren'].median())

# year_biuilt - year renovated  = years since renovated.

# %% [markdown]
# ### Brake down in to Decade Class for year built

# %% [markdown]
# 1900's:

# %%
df_1900 = df.loc[df['yr_built_bands'] == 1900]

# %%
sns.distplot(df_1900['log_price'])

# %%
reg_basic_and_plot(df_1900[''], df_1900['log_price'],
                           "Grade Compare ", "Grade", "Price")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-81-740658103bf0> in <module>
#       1 reg_basic_and_plot(df_1900['grade'], df_1900['log_price'],
# ----> 2                            "Grade Compare ", "Grade", "Price")
#
# <ipython-input-73-8e2cabf1a56b> in reg_basic_and_plot(X, Y, title, X_Lable, Y_Lable)
#      41     c = calc_intercept(X,Y)
#      42     Y_pred = reg_line(m, c, X)
# ---> 43     r = correlation(X,Y)
#      44     r_sqrd = r_squared(Y,Y_pred)
#      45
#
# <ipython-input-7-b5d10ddfc09d> in correlation(var1, var2)
#      30     else:
#      31
# ---> 32         mean_norm_var1 = mean_normalize(var1)
#      33         mean_norm_var2 = mean_normalize(var2)
#      34
#
# <ipython-input-7-b5d10ddfc09d> in mean_normalize(var)
#       2     norm = []
#       3
# ----> 4     mean = sum(var)/len(var)
#       5
#       6     for i in var:
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Now broken down into decade bins:

# %%
sns.barplot(sorted(df['yr_built_bands']), df['price'])

# %%
sns.barplot(df, df['yr_built_bands'], df['yr_renovated'])

# %%
p = sns.FacetGrid(df, col=['df[price_bands]'], row=df['is_ren'])
p = p.map(plt.hist, 'age')

# %%
g = sns.FacetGrid(df, 
              col=sorted(df['yr_built_bands']), 
                         row=sorted(df['price_bands']))

g = g.map(plt.scatter, "price", "age")

# %%
sns.scatterplot(data=df_ren, x=df_ren['age'], y=df_ren['price'])

# %%
reg_basic_and_plot(df_ren['age'], df_ren['price'], "How Price is effect by Age of the Property")

# %% [markdown]
# ### Analysis - Renovated House's
# From the above progression it shows that for every year the price will decrease by just over $2000 . This is a substanitall amount of money but is it significant compared to houses that have not been renovated?
#
# First though as the equation is:
#
#     Price = (-2045.39 * Age) + 924176.48
#
# So lets look at the median house age and return the price.

# %%
df_ren['age'].median()

# %%
-2045.39*(df_ren['age'].median()) + 924176.48

# %%
df_ren.columns

# %%
df_ren['time_to_ren'].mode()

# %% [markdown]
# Check the correlation:

# %%
df_ren.corr()['log_price'].sort_values(ascending=False)

# %%
sns.scatterplot(data=df_non_ren, x=df_non_ren['age'], y=df_non_ren['price'])

# %%
reg_basic_and_plot(df_non_ren['age'], df_non_ren['price'], "How Price is effect by Age of the Property, If a Renovation has been done")

# %% [markdown]
# ### Analysis - If house not Renovated:
#
# I this case the house price does decrease, but only by $996.65 per year.
#
# Benifit of not renovating: re

# %% [markdown]
# Just checking that all the non-renovated house have year built values. As in the initial dataframe the there were yr_bulit values equal to zero.

# %%
# sorted(df_non_ren['yr_built'].unique())

# %% [markdown]
# ## Comparing the finding the mean age of the building in each zipcode.

# %%
def averages_dist_comparison(average, y_condition, x_condition, title):
    stats_y_condition = df.groupby([y_condition])[x_condition].average().apply(lambda x: format(x, 'f'))
    df_stats_y_condition = pd.DataFrame(stats_y_condition)
    avaerage_y_condition = df_stats_y_condition.rename(columns={str(y_condition): str(x_condition)})
    avaerage_y_condition.x_condition = avaerage_y_condition.x_condition.astype('float64')
    df_stats_y_condition = pd.DataFrame(avaerage_y_condition)
    df_stats_y_condition.sort_values(str(y_condition).plot(kind='barh', figsize=(15,15))
    plt.title(title)

# %%
averages_dist_comparison('median', 'zipcode','condition', "test")

# %%
#found Mean price values of houses in each zipcode
stats_zipcode = df.groupby(['zipcode'])['age'].mean().apply(lambda x: format(x, 'f'))
df_stats_zipcode = pd.DataFrame(stats_zipcode)
mean_zipcode = df_stats_zipcode.rename(columns={"age": "mean_price"})
mean_zipcode.mean_price = mean_zipcode.mean_price.astype('float64')
df_mean_zipcode = pd.DataFrame(mean_zipcode)
df_mean_zipcode.sort_values('zipcode').plot(kind='barh', figsize=(15,15))
plt.title('Mean Price in each Zipcode')
# # df_mean_zipcode = df_stats_zipcode.rename(columns={"price": "mean_price"})
# # df2 = df_mean_zipcode['mean_price'].astype('float64')
# # sns.distplot(df_mean_zipcode)
# sns.barplot(x = ['zipcode'], y = ['mean_price'])
# # #clean this graph a little more

# %% [markdown]
# Check differance by median:

# %%
stats_zipcode = df.groupby(['zipcode'])['age'].median().apply(lambda x: format(x, 'f'))
df_stats_zipcode = pd.DataFrame(stats_zipcode)
median_zipcode = df_stats_zipcode.rename(columns={"age": "median_price"})
median_zipcode.median_price = median_zipcode.median_price.astype('float64')
df_median_zipcode = pd.DataFrame(median_zipcode)
df_median_zipcode.sort_values('zipcode').plot(kind='barh', figsize=(15,15))
plt.title('Median Age in each Zipcode')

# %% [markdown]
# Look and median extra space in each zipxode

# %%
stats_zipcode = df.groupby(['zipcode'])['extra_space'].median().apply(lambda x: format(x, 'f'))
df_stats_zipcode = pd.DataFrame(stats_zipcode)
median_zipcode = df_stats_zipcode.rename(columns={"zipcode": "extra_space"})
median_zipcode.extra_space = median_zipcode.extra_space.astype('float64')
df_median_zipcode = pd.DataFrame(median_zipcode)
df_median_zipcode.sort_values('zipcode').plot(kind='barh', figsize=(15,15))
plt.title('Median extra_space in each Zipcode')

# %%
df.plot(kind="scatter", x="long", y="lat", figsize=(16, 8), c="extra_space",
             cmap="gist_heat_r", colorbar=True, sharex=False)
plt.grid(which='both')
plt.title('Property Age as per location')
plt.show()

# %%
df.plot(kind="scatter", x="long", y="lat", figsize=(16, 8), c="age",
             cmap="gist_heat_r", colorbar=True, sharex=False)
plt.grid(which='both')
plt.title('Property Age as per location')
plt.show()

# %% [markdown]
# # Part 2 - Breaking the Houses Clasifications
#
# In this section we will be breaking down the houses into further catagorise and comapreing the non-renovated top the renovated in diffent metrics:
#
#     2a. Price Bands
#     2b. Number of Bedrooms
#     2c. Number of Bathrooms
#     2d. sqft_lot
#     2e. sqft_living
#     2f. Building Condition
#     2g. Building Grade

# %% [markdown]
# ### 2a. Price Band - Renovated

# %%
sns.barplot(y=sorted(df_ren['price_bands']), x=df_ren['age']) # title="Price Bands to age of property"

# %%
sns.scatterplot(y=sorted(df_ren['condition']), x=df_ren['grade'])

# %%
# df_ren.set_index(df_ren['price_bands'])

# %%
sns.lmplot(data=df, x="age", y="grade", hue="price_bands")

# %%
sns.lmplot(data=df, x="age", y="price", hue="yr_built_bands")

# %%
# reg_basic_and_plot()

# %% [markdown]
# ## Renovated - Bedrooms

# %%
sns.barplot(x=df_ren['bedrooms'], y=df_ren['price'])

# %% [markdown]
# ## 2e. Square foot living

# %%
reg_basic_and_plot(df['sqft_living'], df['price'], 'test')

# %%
compare_reg_basic_and_plot(df_non_ren['sqft_living'], df_non_ren['price'], df_ren['sqft_living'], df_ren['price'], 
                           "Price Compared to sqft_living: \nData_1 = Non-Renovated \nData_2 = Renovated")

# %% [markdown]
# ### Square foot living compared to square foot lot

# %%
compare_reg_basic_and_plot(df_non_ren['sqft_living'], df_non_ren['sqft_lot'], df_ren['sqft_living'], df_ren['sqft_lot'], 
                           "Sqft_lot Compared to sqft_living: \nData_1 = Non-Renovated \nData_2 = Renovated")

# %% [markdown]
# This shows that living_space/lot_space  decrease if renovation is completed.

# %%
df['extra_space'] = df['sqft_lot'] - df['sqft_living']

# %% [markdown]
# ## 2f. Condition

# %%
df.plot(kind="scatter", x="long", y="lat", figsize=(16, 8), c="condition",
             cmap="gist_heat", colorbar=True, sharex=False)
plt.grid(which='both')
plt.title('Property Age as per location')
plt.show()

# %%
compare_reg_basic_and_plot(df_non_ren['condition'], df_non_ren['price'], 
                           df_ren['condition'], df_ren['price'], 
                           "Sqft_lot Compared to sqft_living: \nData_1 = Non-Renovated \nData_2 = Renovated",
                          "Condition", "Price")

# %%
sns.distplot(df['condition'])

# %%
(len(df_bad_condition)/len(df))*100

# %%
902107*0.009215096087057189

# %%
df['condition'].describe()

# %%
df_bad_condition = df.loc[df['condition'] < 3]
df_bad_condition.describe()

# %%
df_bad_condition.plot(kind="scatter", x="long", y="lat", figsize=(16, 8), c="price",
             cmap="gist_heat_r", colorbar=True, sharex=False)
plt.grid(which='both')
plt.title('Locations of bad condition houses')
plt.show()

# %%
df.plot(kind="scatter", x="long", y="lat", figsize=(16, 8), c="grade",
             cmap="gist_heat_r", colorbar=True, sharex=False)
plt.grid(which='both')
plt.title('Locations of bad condition houses')
plt.show()

# %%
df.plot(kind="scatter", x="long", y="lat", figsize=(16, 8), c="zipcode",
             cmap="viridis", colorbar=True, sharex=False)
plt.grid(which='both')
plt.title('Locations of bad condition houses')
plt.show()

# %%
len(df['zipcode'].unique())

# %%
stats_zipcode = df.groupby(['zipcode'])['condition'].median().apply(lambda x: format(x, 'f'))
df_stats_zipcode = pd.DataFrame(stats_zipcode)
median_zipcode = df_stats_zipcode.rename(columns={"zipcode": "condition"})
median_zipcode.extra_space = median_zipcode.condition.astype('float64')
df_median_zipcode = pd.DataFrame(median_zipcode)
df_median_zipcode.sort_values('zipcode').plot(kind='barh', figsize=(15,15))
plt.title('Median extra_space in each Zipcode')
